# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x=np.linspace(0,5,11)
y= x **2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Functional
plt.plot(x,y)
#
plt.xlabel('X Label')
plt.ylabel('Y labe')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
#subplot(rows,columns,plot)
plt.subplot(1,2,1)
plt.plot(x,y,'b')


plt.subplot(1,2,2)
plt.plot(y,x,'r')

# %%
#OO

fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'r')
axes.set_xlabel('Xlabel')
axes.set_ylabel('Ylabel')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.5,0.15,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %% [markdown]
# MATPLOTLIB PART 2

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y)

# %%
#Creating subplot using OO
fig,axes = plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)
#Index it
axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')

# When thigs are overlaping you can use method tight_layout
plt.tight_layout()

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# Figure Size and DPI

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X Cubed')

#include Legends

ax.legend(loc=1)

# %%
#Save our figure
fig.savefig('my_picture.png',dpi =200)

# %% [markdown]
# # Plot Appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='green',linewidth=3,linestyle='--',marker='*',ms=20,markerfacecolor='yellow') # you can also use your RGB Hex Code
#Alpha is for setting your transparency
#Linestyle it can be written as ls
# You can incule you markers and also marker size
